# %%
import numpy as np 
import pandas as pd

# %%
df=pd.read_csv('laptop_data.csv')
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %% [markdown]
# #### Making Ram and weight float by removing characters

# %%
df['Ram']=df['Ram'].str.replace('GB','')
df['Weight']=df['Weight'].str.replace('kg','')

# %%
df['Ram']
# Out:
# 0        8
# 1        8
# 2        8
# 3       16
# 4        8
#         ..
# 1298     4
# 1299    16
# 1300     2
# 1301     6
# 1302     4
# Name: Ram, Length: 1303, dtype: object

# %%
df['Ram']=df['Ram'].astype('int32')
df['Weight']=df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %% [markdown]
# ## EDA

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.displot(df.Price)

# %% [markdown]
# ##### Data is skewed as low range laptops are more than higher range laptops

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.displot(df['Inches'])

# %%
sns.scatterplot(df['Inches'],df['Price'],hue=df['Company'])
# Out:
# C:\Users\sharm\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Inches', ylabel='Price'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %% [markdown]
# ### Now doingEDA on  ScreenResolution column

# %%
 df['Touchscreen'] = df['ScreenResolution'].str.contains('Touchscreen', case=False, na=False).astype(int)

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price']);

# %%
# doing this same for IPS panel
df['IPS Panel'] = df['ScreenResolution'].str.contains('IPS', case=False, na=False).astype(int)

# %%
sns.barplot(x=df['IPS Panel'],y=df['Price']);

# %%
input_string = "IPs Display jdjweujnei 2509*1688"

# Splitting the string by non-digit characters
words = input_string.split()

# %%
words
# Out:
# ['IPs', 'Display', 'jdjweujnei', '2509*1688']

# %%
df['Resolution']=0
for i in range(1303):
    df['Resolution'][i]=df['ScreenResolution'][i].split()[-1]
# Out:
# C:\Users\sharm\AppData\Local\Temp\ipykernel_22096\4139471313.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Resolution'][i]=df['ScreenResolution'][i].split()[-1]

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df['ScreenResolution'][1300]
# Out:
# '1366x768'

# %%
df.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS Panel      0.252208
# Name: Price, dtype: float64

# %%
df[['X_res', 'Y_res']] = df['Resolution'].str.split('x', expand=True).astype(int)

# %%
# Creating a column PPI(pixcels per inch) as correlation between X-res and Y_res is same
df['ppi']=(((df['X_res']**2 + df['Y_res']**2)**0.5)/df['Inches']).astype(float)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# ...

# %%
df.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS Panel      0.252208
# X_res          0.556529
# Y_res          0.552809
# ppi            0.473487
# Name: Price, dtype: float64

# %%
df.drop(columns=['ScreenResolution','Resolution'],inplace=True)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                        Cpu  Ram               Memory  \
# 0                     Intel Core i5 2.3GHz    8            128GB SSD
# 1                     Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3                     Intel Core i7 2.7GHz   16            512GB SSD
# 4                     Intel Core i5 3.1GHz    8            256GB SSD
# ...

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0
#
#    IPS Panel         ppi
# 0          1  226.983005
# ...

# %%
df['processor']=1
for i in range(1303):
    df['processor'][i]=" ".join(df['Cpu'][i].split()[:3])
# Out:
# C:\Users\sharm\AppData\Local\Temp\ipykernel_22096\1189447535.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['processor'][i]=" ".join(df['Cpu'][i].split()[:3])

# %%
df.processor
# Out:
# 0            Intel Core i5
# 1            Intel Core i5
# 2            Intel Core i5
# 3            Intel Core i7
# 4            Intel Core i5
#                ...
# 1298         Intel Core i7
# 1299         Intel Core i7
# 1300    Intel Celeron Dual
# 1301         Intel Core i7
# 1302    Intel Celeron Dual
# Name: processor, Length: 1303, dtype: object

# %%
df['Brand']=df['processor']
for i in range(1303):
    if df['processor'][i]=='Intel Core i5' or df['processor'][i]=='Intel Core i7' or df['processor'][i]=='Intel Core i3':
        df['Brand'][i]=df['processor'][i]
    else:
        if df['processor'][i].split()[0]=='Intel':
            df['Brand'][i]='Other Intel Processor'
        else:
            df['Brand'][i]='AMD Processor'
# Out:
# C:\Users\sharm\AppData\Local\Temp\ipykernel_22096\3113721450.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Brand'][i]=df['processor'][i]
# C:\Users\sharm\AppData\Local\Temp\ipykernel_22096\3113721450.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Brand'][i]='AMD Processor'
# C:\Users\sharm\AppData\Local\Temp\ipykernel_22096\3113721450.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df.head(2)
# Out:
#   Company   TypeName                   Cpu  Ram               Memory  \
# 0   Apple  Ultrabook  Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook  Intel Core i5 1.8GHz    8  128GB Flash Storage
#
#                             Gpu  OpSys  Weight       Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232            0
#
#    IPS Panel         ppi      processor          Brand
# 0          1  226.983005  Intel Core i5  Intel Core i5
# 1          0  127.677940  Intel Core i5  Intel Core i5

# %%
df['Brand'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Cpu','processor'],inplace=True)
df
# Out:
#      Company            TypeName  Ram               Memory  \
# 0      Apple           Ultrabook    8            128GB SSD
# 1      Apple           Ultrabook    8  128GB Flash Storage
# 2         HP            Notebook    8            256GB SSD
# 3      Apple           Ultrabook   16            512GB SSD
# 4      Apple           Ultrabook    8            256GB SSD
# ...      ...                 ...  ...                  ...
# 1298  Lenovo  2 in 1 Convertible    4            128GB SSD
# 1299  Lenovo  2 in 1 Convertible   16            512GB SSD
# 1300  Lenovo            Notebook    2   64GB Flash Storage
# 1301      HP            Notebook    6              1TB HDD
# 1302    Asus            Notebook    4            500GB HDD
#
#                                Gpu       OpSys  Weight        Price  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# ...

# %%
# Correlation of Price with Ram
sns.barplot(x=df['Ram'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['HDD']=0
df['SSD']=0
df['Flash Storage']=0
df['Hybrid']=0

# %%
df
# Out:
#      Company            TypeName  Ram               Memory  \
# 0      Apple           Ultrabook    8            128GB SSD
# 1      Apple           Ultrabook    8  128GB Flash Storage
# 2         HP            Notebook    8            256GB SSD
# 3      Apple           Ultrabook   16            512GB SSD
# 4      Apple           Ultrabook    8            256GB SSD
# ...      ...                 ...  ...                  ...
# 1298  Lenovo  2 in 1 Convertible    4            128GB SSD
# 1299  Lenovo  2 in 1 Convertible   16            512GB SSD
# 1300  Lenovo            Notebook    2   64GB Flash Storage
# 1301      HP            Notebook    6              1TB HDD
# 1302    Asus            Notebook    4            500GB HDD
#
#                                Gpu       OpSys  Weight        Price  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# ...

# %%
for i in range(1303):
    word=df['Memory'][i].split()
    for j in range(len(word)):
        if word[j]=='SSD':
            df['SSD'][i]=word[j-1]
            
        elif word[j]=='HDD':
            df['HDD'][i]=word[j-1]
            
        elif word[j]=='Flash': 
            df['Flash Storage'][i]=word[j-1]
            
        elif word[j]=='Hybrid':
            df['Hybrid'][i]=word[j-1]
# Out:
# C:\Users\sharm\AppData\Local\Temp\ipykernel_22096\981305077.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SSD'][i]=word[j-1]
# C:\Users\sharm\AppData\Local\Temp\ipykernel_22096\981305077.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Flash Storage'][i]=word[j-1]
# C:\Users\sharm\AppData\Local\Temp\ipykernel_22096\981305077.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
a=df['HDD'][1301].split()
a[0][:-2]
# Out:
# '1'

# %%
def integer(a):
    for i in range(1303):
        if a[i]!=0:
            word=a[i].split()
            a[i]=word[0][:-2]
integer(df['HDD'])
integer(df['SSD'])
integer(df['Hybrid'])
integer(df['Flash Storage'])

# %%
df['HDD'][1301]
# Out:
# '1'

# %%
df.sample(20)
# Out:
#       Company     TypeName  Ram                Memory  \
# 33       Dell    Ultrabook   16             512GB SSD
# 981   Toshiba     Notebook    4             128GB SSD
# 464    Lenovo     Notebook    8             256GB SSD
# 955      Dell       Gaming   16  512GB SSD +  1TB HDD
# 938      Dell    Ultrabook    8             256GB SSD
# 715    Lenovo     Notebook    8             256GB SSD
# 45      Apple    Ultrabook    8             256GB SSD
# 1109     Asus       Gaming   16  128GB SSD +  1TB HDD
# 297      Dell  Workstation   16             256GB SSD
# 271      Asus       Gaming   16  256GB SSD +  1TB HDD
# 635      Asus     Notebook    8               1TB HDD
# 646      Acer    Ultrabook    8             256GB SSD
# 261    Lenovo     Notebook    4             256GB SSD
# 1049     Asus      Netbook    4    16GB Flash Storage
# 81      Apple    Ultrabook    8             512GB SSD
# 1115     Dell    Ultrabook    8             256GB SSD
# ...

# %%
def making_1TB_1000GB(a):
    for i in range(1303):
        if a[i]=='1':
            a[i]='1000'
#     a.astype(int)
making_1TB_1000GB(df['SSD'])
making_1TB_1000GB(df['HDD'])
making_1TB_1000GB(df['Hybrid'])
making_1TB_1000GB(df['Flash Storage'])
# Out:
# C:\Users\sharm\AppData\Local\Temp\ipykernel_22096\2120485047.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[i]='1000'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        1303 non-null   object
#  1   TypeName       1303 non-null   object
#  2   Ram            1303 non-null   int32
#  3   Memory         1303 non-null   object
#  4   Gpu            1303 non-null   object
#  5   OpSys          1303 non-null   object
#  6   Weight         1303 non-null   float32
#  7   Price          1303 non-null   float64
#  8   Touchscreen    1303 non-null   int32
#  9   IPS Panel      1303 non-null   int32
#  10  ppi            1303 non-null   float64
#  11  Brand          1303 non-null   object
#  12  HDD            1303 non-null   object
#  13  SSD            1303 non-null   object
#  14  Flash Storage  1303 non-null   object
#  15  Hybrid         1303 non-null   object
# dtypes: float32(1), float64(2), int32(3), object(10)
# ...

# %%
df['HDD']=df['HDD'].astype('float32')
df['SSD']=df['SSD'].astype('float32')
df['Hybrid']=df['Hybrid'].astype('float32')
df['Flash Storage']=df['Flash Storage'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        1303 non-null   object
#  1   TypeName       1303 non-null   object
#  2   Ram            1303 non-null   int32
#  3   Memory         1303 non-null   object
#  4   Gpu            1303 non-null   object
#  5   OpSys          1303 non-null   object
#  6   Weight         1303 non-null   float32
#  7   Price          1303 non-null   float64
#  8   Touchscreen    1303 non-null   int32
#  9   IPS Panel      1303 non-null   int32
#  10  ppi            1303 non-null   float64
#  11  Brand          1303 non-null   object
#  12  HDD            1303 non-null   float32
#  13  SSD            1303 non-null   float32
#  14  Flash Storage  1303 non-null   float32
#  15  Hybrid         1303 non-null   float32
# dtypes: float32(5), float64(2), int32(3), object(6)
# ...

# %%
df
# Out:
#      Company            TypeName  Ram               Memory  \
# 0      Apple           Ultrabook    8            128GB SSD
# 1      Apple           Ultrabook    8  128GB Flash Storage
# 2         HP            Notebook    8            256GB SSD
# 3      Apple           Ultrabook   16            512GB SSD
# 4      Apple           Ultrabook    8            256GB SSD
# ...      ...                 ...  ...                  ...
# 1298  Lenovo  2 in 1 Convertible    4            128GB SSD
# 1299  Lenovo  2 in 1 Convertible   16            512GB SSD
# 1300  Lenovo            Notebook    2   64GB Flash Storage
# 1301      HP            Notebook    6              1TB HDD
# 1302    Asus            Notebook    4            500GB HDD
#
#                                Gpu       OpSys  Weight        Price  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# ...

# %%
df['HDD']=df['HDD'].astype('int32')
df['SSD']=df['SSD'].astype('int32')
df['Hybrid']=df['Hybrid'].astype('int32')
df['Flash Storage']=df['Flash Storage'].astype('int32')

# %%
df
# Out:
#      Company            TypeName  Ram               Memory  \
# 0      Apple           Ultrabook    8            128GB SSD
# 1      Apple           Ultrabook    8  128GB Flash Storage
# 2         HP            Notebook    8            256GB SSD
# 3      Apple           Ultrabook   16            512GB SSD
# 4      Apple           Ultrabook    8            256GB SSD
# ...      ...                 ...  ...                  ...
# 1298  Lenovo  2 in 1 Convertible    4            128GB SSD
# 1299  Lenovo  2 in 1 Convertible   16            512GB SSD
# 1300  Lenovo            Notebook    2   64GB Flash Storage
# 1301      HP            Notebook    6              1TB HDD
# 1302    Asus            Notebook    4            500GB HDD
#
#                                Gpu       OpSys  Weight        Price  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# ...

# %%
df.drop(columns=['Memory'],inplace=True)
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS Panel         ppi          Brand  HDD  SSD  \
# 0   71378.6832            0          1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0          0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0          0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0          1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0          1  226.983005  Intel Core i5    0  256
#
#    Flash Storage  Hybrid
# 0              0       0
# 1            128       0
# ...

# %%
df['gpu brand']=0
for i in range(1303):
    df['gpu brand'][i]=df['Gpu'][i].split()[0]
# Out:
# C:\Users\sharm\AppData\Local\Temp\ipykernel_22096\3153830354.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gpu brand'][i]=df['Gpu'][i].split()[0]

# %%
df.drop(columns=['Gpu'],inplace=True)

# %%
df['gpu brand'].value_counts()
df=df[df['gpu brand']!='ARM']

# %%
df.reset_index(drop=True, inplace=True)

# %%
df['gpu brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: gpu brand, dtype: int64

# %%
sns.barplot(x=df['gpu brand'],y=df['Price']);

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
df['op s']=0
for i in range(1302):
    word=df['OpSys'][i].split()
    if word[0]=='Windows':
        df['op s'][i]='Windows'
    elif word[0]=='macOS' or word[0]=='Mac':
        df['op s'][i]='MacOS'
    else:
        df['op s'][i]='Other'
# Out:
# C:\Users\sharm\AppData\Local\Temp\ipykernel_22096\4170814726.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['op s']=0
# C:\Users\sharm\AppData\Local\Temp\ipykernel_22096\4170814726.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['op s'][i]='MacOS'
# C:\Users\sharm\AppData\Local\Temp\ipykernel_22096\4170814726.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df
# Out:
#      Company            TypeName  Ram       OpSys  Weight        Price  \
# 0      Apple           Ultrabook    8       macOS    1.37   71378.6832
# 1      Apple           Ultrabook    8       macOS    1.34   47895.5232
# 2         HP            Notebook    8       No OS    1.86   30636.0000
# 3      Apple           Ultrabook   16       macOS    1.83  135195.3360
# 4      Apple           Ultrabook    8       macOS    1.37   96095.8080
# ...      ...                 ...  ...         ...     ...          ...
# 1297  Lenovo  2 in 1 Convertible    4  Windows 10    1.80   33992.6400
# 1298  Lenovo  2 in 1 Convertible   16  Windows 10    1.30   79866.7200
# 1299  Lenovo            Notebook    2  Windows 10    1.50   12201.1200
# 1300      HP            Notebook    6  Windows 10    2.19   40705.9200
# 1301    Asus            Notebook    4  Windows 10    2.20   19660.3200
#
#       Touchscreen  IPS Panel         ppi                  Brand   HDD  SSD  \
# ...

# %%
sns.barplot(x=df['op s'],y=df['Price']);

# %%
sns.displot(df['Weight'])

# %% [markdown]
# ## After doing EDA Let's find Correlation of each column

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df.drop(columns=['OpSys','Flash Storage','Hybrid'],inplace=True)
# Out:
# C:\Users\sharm\AppData\Local\Temp\ipykernel_22096\74497405.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['OpSys','Flash Storage','Hybrid'],inplace=True)

# %% [markdown]
# ### After doing all Analysis let's Train our model

# %%
# Making input and output variables
X=df.drop(columns=['Price'])
Y=np.log(df.Price)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.15,random_state=3)

# %%
# As we have categorical columns like brand name, op s ,etc. so we will do OneHotEncoding
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.metrics import r2_score,mean_absolute_error
from xgboost import XGBRegressor

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  IPS Panel  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0          1
# 1   Apple  Ultrabook    8    1.34   47895.5232            0          0
# 2      HP   Notebook    8    1.86   30636.0000            0          0
# 3   Apple  Ultrabook   16    1.83  135195.3360            0          1
# 4   Apple  Ultrabook    8    1.37   96095.8080            0          1
#
#           ppi          Brand  HDD  SSD gpu brand   op s
# 0  226.983005  Intel Core i5    0  128     Intel  MacOS
# 1  127.677940  Intel Core i5    0    0     Intel  MacOS
# 2  141.211998  Intel Core i5    0  256     Intel  Other
# 3  220.534624  Intel Core i7    0  512       AMD  MacOS
# 4  226.983005  Intel Core i5    0  256     Intel  MacOS

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = LinearRegression()

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(X_train,Y_train)
y_pred=pipe.predict(X_test)
print('r2_score= ',r2_score(Y_test,y_pred))
print('mae= ',mean_absolute_error(Y_test,y_pred))
# Out:
# r2_score=  0.7969745103032994
# mae=  0.22379964152573265

# %% [markdown]
# ## Let's Try with XgBoost

# %%
step1= ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')
step2= XGBRegressor(n_estimators=45,max_depth=5,learning_rate=0.5)
pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(X_train,Y_train)
y_pred = pipe.predict(X_test)
print('r2_score= ',r2_score(Y_test,y_pred))
print('mae= ',mean_absolute_error(Y_test,y_pred))
# Out:
# r2_score=  0.8649616733210075
# mae=  0.16751688885160676

# %% [markdown]
# ### I've used two models and with XgBoost i'm getting highest r2_score so using this to export model
#
# ## Exporting Model

# %%
import pickle
pickle.dump(df,open('df2.pkl','wb'))
pickle.dump(pipe,open('pipe2.pkl','wb'))

# %%
import sklearn
sklearn.__version__
# Out:
# '1.0.2'

# %%
pip --upgrade scikit-learn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Usage:
#   C:\Users\sharm\anaconda3\python.exe -m pip <command> [options]
#
# no such option: --upgrade

# %%
pip uninstall sklearn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping sklearn as it is not installed.
